# %%
from __future__ import division, print_function
# %matplotlib inline
import matplotlib.pyplot as plt
import matplotlib
import numpy as np

# %%
import sys
sys.path.append('..')

# %%
from tf_unet import image_util_fbp
from tf_unet import unet
from tf_unet import util

# %%
generator = image_util_fbp.FBPDataProvider("/home/urota/git/tf_unet/data_512/*.png", data_suffix=".png", mask_suffix="_reconst.png")
# Out:
# Number of files used: 474
# Number of channels: 1
# Number of classes: 2

# %%
x_test, y_test= generator(1)
print(generator.len())
# Out:
# 474

# %%
plt.gray()
fig, ax = plt.subplots(1,2, sharey=True, figsize=(8,4))
print(y_test.shape)
print(np.min(x_test), np.max(x_test))
print(np.min(y_test), np.max(y_test))
ax[0].imshow(x_test[0, ..., 0], aspect="auto")
ax[1].imshow(y_test[0, ..., 0], aspect="auto")
# Out:
# (1, 512, 512, 1)
# -256.0 254.0
# -136.0 254.0

# %%
net = unet.Unet(channels=generator.channels, n_class=generator.n_class, cost="euclidean", layers=5, features_root=32)
# Out:
# WARNING: Logging before flag parsing goes to stderr.
# W0920 05:21:03.554091 139905302885760 deprecation_wrapper.py:119] From ../tf_unet/unet.py:193: The name tf.reset_default_graph is deprecated. Please use tf.compat.v1.reset_default_graph instead.
#
# W0920 05:21:03.559104 139905302885760 deprecation_wrapper.py:119] From ../tf_unet/unet.py:198: The name tf.placeholder is deprecated. Please use tf.compat.v1.placeholder instead.
#
# W0920 05:21:03.581605 139905302885760 deprecation_wrapper.py:119] From ../tf_unet/layers.py:25: The name tf.truncated_normal is deprecated. Please use tf.random.truncated_normal instead.
#
# W0920 05:21:03.598602 139905302885760 deprecation.py:506] From ../tf_unet/layers.py:39: calling dropout (from tensorflow.python.ops.nn_ops) with keep_prob is deprecated and will be removed in a future version.
# Instructions for updating:
# Please use `rate` instead of `keep_prob`. Rate should be set to `rate = 1 - keep_prob`.
# W0920 05:21:03.618577 139905302885760 deprecation_wrapper.py:119] From ../tf_unet/layers.py:48: The name tf.nn.max_pool is deprecated. Please use tf.nn.max_pool2d instead.
#
# W0920 05:21:04.125844 139905302885760 deprecation_wrapper.py:119] From ../tf_unet/unet.py:155: The name tf.summary.image is deprecated. Please use tf.compat.v1.summary.image instead.
# Tensor("output_map/conv2d/dropout/mul_1:0", shape=(?, ?, ?, 1), dtype=float32)
# Tensor("preprocessing/Reshape:0", shape=(?, ?, ?, 1), dtype=float32)
# W0920 05:21:04.521157 139905302885760 deprecation_wrapper.py:119] From ../tf_unet/unet.py:165: The name tf.summary.histogram is deprecated. Please use tf.compat.v1.summary.histogram instead.
#
# W0920 05:21:04.971220 139905302885760 deprecation_wrapper.py:119] From ../tf_unet/layers.py:68: The name tf.log is deprecated. Please use tf.math.log instead.

# %%
trainer = unet.Trainer(net, optimizer="adam", batch_size=1, opt_kwargs=dict(learning_rate=0.0001))

# %%
path = trainer.train(generator, "./unet_trained512", training_iters=generator.len(), epochs=101, display_step=2, restore=True)
# Out:
# W0920 05:21:10.375412 139905302885760 deprecation_wrapper.py:119] From ../tf_unet/unet.py:366: The name tf.summary.scalar is deprecated. Please use tf.compat.v1.summary.scalar instead.
#
# W0920 05:21:10.381820 139905302885760 deprecation_wrapper.py:119] From ../tf_unet/unet.py:352: The name tf.train.AdamOptimizer is deprecated. Please use tf.compat.v1.train.AdamOptimizer instead.
#
# W0920 05:21:11.272684 139905302885760 deprecation_wrapper.py:119] From ../tf_unet/unet.py:373: The name tf.summary.merge_all is deprecated. Please use tf.compat.v1.summary.merge_all instead.
#
# W0920 05:21:11.277215 139905302885760 deprecation_wrapper.py:119] From ../tf_unet/unet.py:374: The name tf.global_variables_initializer is deprecated. Please use tf.compat.v1.global_variables_initializer instead.
#
# W0920 05:21:14.942395 139905302885760 deprecation_wrapper.py:119] From ../tf_unet/unet.py:431: The name tf.summary.FileWriter is deprecated. Please use tf.compat.v1.summary.FileWriter instead.
# min data: -256.0
# max data: 254.0
# min gt: -256.0
# max gt: 254.0
# min pred: -261.62366
# max pred: 255.03922
# epoch 0
# step 474 : loss 392977.996134
# W0920 05:24:46.076833 139905302885760 deprecation_wrapper.py:119] From ../tf_unet/unet.py:295: The name tf.train.Saver is deprecated. Please use tf.compat.v1.train.Saver instead.
# min data: -256.0
# max data: 254.0
# min gt: -256.0
# max gt: 254.0
# min pred: -286.88397
# max pred: 279.59787
# epoch 1
# step 474 : loss 391494.237465
# min data: -256.0
# max data: 254.0
# min gt: -256.0
# max gt: 254.0
# min pred: -291.42798
# max pred: 332.8016
# epoch 2
# step 474 : loss 392534.100532
# min data: -256.0
# max data: 254.0
# min gt: -256.0
# max gt: 254.0
# min pred: -298.10327
# max pred: 350.22974
# epoch 3
# step 474 : loss 382955.224115
# min data: -256.0
# max data: 254.0
# min gt: -256.0
# max gt: 254.0
# min pred: -285.78644
# max pred: 364.4633
# epoch 4
# step 474 : loss 365828.343822
# min data: -256.0
# max data: 254.0
# min gt: -256.0
# max gt: 254.0
# min pred: -281.0087
# max pred: 405.06952
# epoch 5
# step 474 : loss 342373.036778
# min data: -256.0
# max data: 254.0
# min gt: -256.0
# max gt: 254.0
# min pred: -293.73312
# max pred: 428.17682
# epoch 6
# step 474 : loss 266008.328619
# min data: -256.0
# max data: 254.0
# min gt: -256.0
# max gt: 254.0
# min pred: -298.17175
# max pred: 362.729
# epoch 7
# step 474 : loss 223171.116011
# min data: -256.0
# max data: 254.0
# min gt: -256.0
# max gt: 254.0
# min pred: -297.59695
# max pred: 420.23914
# epoch 8
# step 474 : loss 199535.245575
# min data: -256.0
# max data: 254.0
# min gt: -256.0
# max gt: 254.0
# min pred: -302.46222
# max pred: 425.2951
# epoch 9
# step 474 : loss 181190.716518
# min data: -256.0
# max data: 254.0
# min gt: -256.0
# max gt: 254.0
# min pred: -298.18622
# max pred: 391.21112
# epoch 10
# step 474 : loss 198025.305283
# min data: -256.0
# max data: 254.0
# min gt: -256.0
# max gt: 254.0
# min pred: -294.29666
# max pred: 593.896
# epoch 11
# step 474 : loss 146793.924801
# min data: -256.0
# max data: 254.0
# min gt: -256.0
# max gt: 254.0
# min pred: -301.49118
# max pred: 593.28406
# epoch 12
# step 474 : loss 139492.764156
# min data: -256.0
# max data: 254.0
# min gt: -256.0
# max gt: 254.0
# min pred: -296.79718
# max pred: 525.0629
# epoch 13
# step 474 : loss 144278.793162
# min data: -256.0
# max data: 254.0
# min gt: -256.0
# max gt: 254.0
# min pred: -302.80185
# max pred: 548.34924
# epoch 14
# step 474 : loss 132491.897525
# min data: -256.0
# max data: 254.0
# min gt: -256.0
# max gt: 254.0
# min pred: -301.69385
# max pred: 644.6463
# epoch 15
# step 474 : loss 120506.841296
# min data: -256.0
# max data: 254.0
# min gt: -256.0
# max gt: 254.0
# min pred: -305.31885
# max pred: 584.33307
# epoch 16
# step 474 : loss 115365.246339
# min data: -256.0
# max data: 254.0
# min gt: -256.0
# max gt: 254.0
# min pred: -301.77972
# max pred: 549.8395
# epoch 17
# step 474 : loss 115151.684828
# min data: -256.0
# max data: 254.0
# min gt: -256.0
# max gt: 254.0
# min pred: -310.93414
# max pred: 508.55856
# epoch 18
# step 474 : loss 113490.445422
# min data: -256.0
# max data: 254.0
# min gt: -256.0
# max gt: 254.0
# min pred: -305.65665
# max pred: 523.50757
# epoch 19
# step 474 : loss 116562.628154
# min data: -256.0
# max data: 254.0
# min gt: -256.0
# max gt: 254.0
# min pred: -321.25888
# max pred: 514.5265
# epoch 20
# step 474 : loss 121333.800697
# min data: -256.0
# max data: 254.0
# min gt: -256.0
# max gt: 254.0
# min pred: -310.3895
# max pred: 538.87463
# epoch 21
# step 474 : loss 103146.699153
# min data: -256.0
# max data: 254.0
# min gt: -256.0
# max gt: 254.0
# min pred: -315.0498
# max pred: 417.15295
# epoch 22
# step 474 : loss 103038.988984
# min data: -256.0
# max data: 254.0
# min gt: -256.0
# max gt: 254.0
# min pred: -316.5789
# max pred: 491.94855
# epoch 23
# step 474 : loss 101325.554788
# min data: -256.0
# max data: 254.0
# min gt: -256.0
# max gt: 254.0
# min pred: -316.98236
# max pred: 502.3368
# epoch 24
# step 474 : loss 99857.3039582
# min data: -256.0
# max data: 254.0
# min gt: -256.0
# max gt: 254.0
# min pred: -320.2368
# max pred: 492.6133
# epoch 25
# step 474 : loss 103090.497289
# min data: -256.0
# max data: 254.0
# min gt: -256.0
# max gt: 254.0
# min pred: -312.29742
# max pred: 503.6112
# epoch 26
# step 474 : loss 100236.625634
# min data: -256.0
# max data: 254.0
# min gt: -256.0
# max gt: 254.0
# min pred: -320.60092
# max pred: 511.7311
# epoch 27
# step 474 : loss 95082.4347475
# min data: -256.0
# max data: 254.0
# min gt: -256.0
# max gt: 254.0
# min pred: -322.27252
# max pred: 458.1349
# epoch 28
# step 474 : loss 95904.0465124
# min data: -256.0
# max data: 254.0
# min gt: -256.0
# max gt: 254.0
# min pred: -324.99942
# max pred: 452.85037
# epoch 29
# step 474 : loss 95413.7484157
# min data: -256.0
# max data: 254.0
# min gt: -256.0
# max gt: 254.0
# min pred: -330.0618
# max pred: 384.53772
# epoch 30
# step 474 : loss 94285.4762226
# min data: -256.0
# max data: 254.0
# min gt: -256.0
# max gt: 254.0
# min pred: -325.2521
# max pred: 421.54224
# epoch 31
# step 474 : loss 91918.5419489
# min data: -256.0
# max data: 254.0
# min gt: -256.0
# max gt: 254.0
# min pred: -323.96564
# max pred: 400.97223
# epoch 32
# step 474 : loss 88033.9023231
# min data: -256.0
# max data: 254.0
# min gt: -256.0
# max gt: 254.0
# min pred: -317.35156
# max pred: 589.59424
# epoch 33
# step 474 : loss 93744.8959281
# min data: -256.0
# max data: 254.0
# min gt: -256.0
# max gt: 254.0
# min pred: -318.89905
# max pred: 404.09363
# epoch 34
# step 474 : loss 92397.0881914
# min data: -256.0
# max data: 254.0
# min gt: -256.0
# max gt: 254.0
# min pred: -324.84076
# max pred: 405.40704
# epoch 35
# step 474 : loss 85082.8012798
# min data: -256.0
# max data: 254.0
# min gt: -256.0
# max gt: 254.0
# min pred: -321.83685
# max pred: 398.4154
# epoch 36
# step 474 : loss 86176.6269325
# min data: -256.0
# max data: 254.0
# min gt: -256.0
# max gt: 254.0
# min pred: -323.60236
# max pred: 404.16345
# epoch 37
# step 474 : loss 86394.3120941
# min data: -256.0
# max data: 254.0
# min gt: -256.0
# max gt: 254.0
# min pred: -309.00677
# max pred: 416.60217
# epoch 38
# step 474 : loss 84649.9004566
# min data: -256.0
# max data: 254.0
# min gt: -256.0
# max gt: 254.0
# min pred: -322.22507
# max pred: 491.44095
# epoch 39
# step 474 : loss 82523.0737696
# min data: -256.0
# max data: 254.0
# min gt: -256.0
# max gt: 254.0
# min pred: -310.18677
# max pred: 458.48102
# epoch 40
# step 474 : loss 84074.8154565
# min data: -256.0
# max data: 254.0
# min gt: -256.0
# max gt: 254.0
# min pred: -301.56787
# max pred: 445.93695
# epoch 41
# step 474 : loss 82181.2191538
# min data: -256.0
# max data: 254.0
# min gt: -256.0
# max gt: 254.0
# min pred: -299.0446
# max pred: 470.96295
# epoch 42
# step 474 : loss 81232.2796039
# min data: -256.0
# max data: 254.0
# min gt: -256.0
# max gt: 254.0
# min pred: -305.91455
# max pred: 471.28027
# epoch 43
# step 474 : loss 79967.8902068
# min data: -256.0
# max data: 254.0
# min gt: -256.0
# max gt: 254.0
# min pred: -301.71118
# max pred: 470.29123
# epoch 44
# step 474 : loss 76648.2107871
# min data: -256.0
# max data: 254.0
# min gt: -256.0
# max gt: 254.0
# min pred: -307.3646
# max pred: 451.14514
# epoch 45
# step 474 : loss 77424.1964209
# min data: -256.0
# max data: 254.0
# min gt: -256.0
# max gt: 254.0
# min pred: -312.85016
# max pred: 457.6093
# epoch 46
# step 474 : loss 76924.0715548
# min data: -256.0
# max data: 254.0
# min gt: -256.0
# max gt: 254.0
# min pred: -307.9707
# max pred: 421.0371
# epoch 47
# step 474 : loss 77251.8408435
# min data: -256.0
# max data: 254.0
# min gt: -256.0
# max gt: 254.0
# min pred: -311.21902
# max pred: 443.50006
# epoch 48
# step 474 : loss 74072.8683536
# min data: -256.0
# max data: 254.0
# min gt: -256.0
# max gt: 254.0
# min pred: -315.8537
# max pred: 435.70673
# epoch 49
# step 474 : loss 73548.7577266
# min data: -256.0
# max data: 254.0
# min gt: -256.0
# max gt: 254.0
# min pred: -312.59338
# max pred: 593.58746
# epoch 50
# step 474 : loss 76252.0022951
# min data: -256.0
# max data: 254.0
# min gt: -256.0
# max gt: 254.0
# min pred: -322.29523
# max pred: 432.5614
# epoch 51
# step 474 : loss 73328.7092769
# min data: -256.0
# max data: 254.0
# min gt: -256.0
# max gt: 254.0
# min pred: -321.2936
# max pred: 451.36694
# epoch 52
# step 474 : loss 69868.5298494
# min data: -256.0
# max data: 254.0
# min gt: -256.0
# max gt: 254.0
# min pred: -318.17032
# max pred: 403.11862
# epoch 53
# step 474 : loss 71372.5745566
# min data: -256.0
# max data: 254.0
# min gt: -256.0
# max gt: 254.0
# min pred: -313.03738
# max pred: 411.8584
# epoch 54
# step 474 : loss 70861.3397201
# min data: -256.0
# max data: 254.0
# min gt: -256.0
# max gt: 254.0
# min pred: -323.86902
# max pred: 437.035
# epoch 55
# step 474 : loss 72065.4019894
# min data: -256.0
# max data: 254.0
# min gt: -256.0
# max gt: 254.0
# min pred: -319.4337
# max pred: 469.72495
# epoch 56
# step 474 : loss 70330.3287451
# min data: -256.0
# max data: 254.0
# min gt: -256.0
# max gt: 254.0
# min pred: -321.1107
# max pred: 486.40533
# epoch 57
# step 474 : loss 70412.7920045
# min data: -256.0
# max data: 254.0
# min gt: -256.0
# max gt: 254.0
# min pred: -320.54474
# max pred: 557.0447
# epoch 58
# step 474 : loss 67554.0612597
# min data: -256.0
# max data: 254.0
# min gt: -256.0
# max gt: 254.0
# min pred: -313.20206
# max pred: 387.58908
# epoch 59
# step 474 : loss 66092.6233209
# min data: -256.0
# max data: 254.0
# min gt: -256.0
# max gt: 254.0
# min pred: -312.83777
# max pred: 399.50275
# epoch 60
# step 474 : loss 67171.1482624
# min data: -256.0
# max data: 254.0
# min gt: -256.0
# max gt: 254.0
# min pred: -313.64505
# max pred: 425.34576
# epoch 61
# step 474 : loss 67699.5363718
# min data: -256.0
# max data: 254.0
# min gt: -256.0
# max gt: 254.0
# min pred: -325.40042
# max pred: 387.4148
# epoch 62
# step 474 : loss 70330.0402368
# min data: -256.0
# max data: 254.0
# min gt: -256.0
# max gt: 254.0
# min pred: -312.3151
# max pred: 416.09464
# epoch 63
# step 474 : loss 66558.3082827
# min data: -256.0
# max data: 254.0
# min gt: -256.0
# max gt: 254.0
# min pred: -311.70956
# max pred: 394.56482
# epoch 64
# step 474 : loss 66561.8180936
# min data: -256.0
# max data: 254.0
# min gt: -256.0
# max gt: 254.0
# min pred: -323.55994
# max pred: 473.76828
# epoch 65
# step 474 : loss 63510.2213336
# min data: -256.0
# max data: 254.0
# min gt: -256.0
# max gt: 254.0
# min pred: -321.3068
# max pred: 443.29602
# epoch 66
# step 474 : loss 64741.0299088
# min data: -256.0
# max data: 254.0
# min gt: -256.0
# max gt: 254.0
# min pred: -305.47128
# max pred: 437.8264
# epoch 67
# step 474 : loss 62816.6929329
# min data: -256.0
# max data: 254.0
# min gt: -256.0
# max gt: 254.0
# min pred: -310.60812
# max pred: 475.5886
# epoch 68
# step 474 : loss 63869.4115881
# min data: -256.0
# max data: 254.0
# min gt: -256.0
# max gt: 254.0
# min pred: -309.85605
# max pred: 378.7904
# epoch 69
# step 474 : loss 62149.4271513
# min data: -256.0
# max data: 254.0
# min gt: -256.0
# max gt: 254.0
# min pred: -324.86884
# max pred: 468.85065
# epoch 70
# step 474 : loss 60543.3536835
# min data: -256.0
# max data: 254.0
# min gt: -256.0
# max gt: 254.0
# min pred: -306.28268
# max pred: 478.55206
# epoch 71
# step 474 : loss 62233.3958436
# min data: -256.0
# max data: 254.0
# min gt: -256.0
# max gt: 254.0
# min pred: -314.93323
# max pred: 416.3555
# epoch 72
# step 474 : loss 61155.3604299
# min data: -256.0
# max data: 254.0
# min gt: -256.0
# max gt: 254.0
# min pred: -315.036
# max pred: 375.48773
# epoch 73
# step 474 : loss 60988.2453994
# min data: -256.0
# max data: 254.0
# min gt: -256.0
# max gt: 254.0
# min pred: -311.49924
# max pred: 409.67426
# epoch 74
# step 474 : loss 62922.1942103
# min data: -256.0
# max data: 254.0
# min gt: -256.0
# max gt: 254.0
# min pred: -320.9839
# max pred: 469.1917
# epoch 75
# step 474 : loss 61406.9018843
# min data: -256.0
# max data: 254.0
# min gt: -256.0
# max gt: 254.0
# min pred: -311.63647
# max pred: 373.09344
# epoch 76
# step 474 : loss 57624.7729945
# min data: -256.0
# max data: 254.0
# min gt: -256.0
# max gt: 254.0
# min pred: -306.0654
# max pred: 418.05557
# epoch 77
# step 474 : loss 58589.0328725
# min data: -256.0
# max data: 254.0
# min gt: -256.0
# max gt: 254.0
# min pred: -324.4225
# max pred: 347.6251
# epoch 78
# step 474 : loss 66417.5219376
# min data: -256.0
# max data: 254.0
# min gt: -256.0
# max gt: 254.0
# min pred: -323.59943
# max pred: 413.4021
# epoch 79
# step 474 : loss 56489.9556159
# min data: -256.0
# max data: 254.0
# min gt: -256.0
# max gt: 254.0
# min pred: -312.04065
# max pred: 377.15234
# epoch 80
# step 474 : loss 57728.3012634
# min data: -256.0
# max data: 254.0
# min gt: -256.0
# max gt: 254.0
# min pred: -321.89557
# max pred: 355.14526
# epoch 81
# step 474 : loss 59644.8316068
# min data: -256.0
# max data: 254.0
# min gt: -256.0
# max gt: 254.0
# min pred: -315.14633
# max pred: 395.11475
# epoch 82
# step 474 : loss 57580.0611526
# min data: -256.0
# max data: 254.0
# min gt: -256.0
# max gt: 254.0
# min pred: -316.90445
# max pred: 417.8522
# epoch 83
# step 474 : loss 57438.9120682
# min data: -256.0
# max data: 254.0
# min gt: -256.0
# max gt: 254.0
# min pred: -316.23492
# max pred: 382.60773
# epoch 84
# step 474 : loss 56684.6499209
# min data: -256.0
# max data: 254.0
# min gt: -256.0
# max gt: 254.0
# min pred: -312.7027
# max pred: 407.54858
# epoch 85
# step 474 : loss 56793.2448741
# min data: -256.0
# max data: 254.0
# min gt: -256.0
# max gt: 254.0
# min pred: -300.8739
# max pred: 362.66345
# epoch 86
# step 474 : loss 56650.9032894
# min data: -256.0
# max data: 254.0
# min gt: -256.0
# max gt: 254.0
# min pred: -317.5573
# max pred: 366.45337
# epoch 87
# step 474 : loss 56943.3787425
# min data: -256.0
# max data: 254.0
# min gt: -256.0
# max gt: 254.0
# min pred: -325.29333
# max pred: 385.6264
# epoch 88
# step 474 : loss 54308.7514813
# min data: -256.0
# max data: 254.0
# min gt: -256.0
# max gt: 254.0
# min pred: -320.34125
# max pred: 400.41315
# epoch 89
# step 474 : loss 54533.6938889
# min data: -256.0
# max data: 254.0
# min gt: -256.0
# max gt: 254.0
# min pred: -302.87082
# max pred: 360.55893
# epoch 90
# step 474 : loss 56209.3601929
# min data: -256.0
# max data: 254.0
# min gt: -256.0
# max gt: 254.0
# min pred: -323.24313
# max pred: 427.12695
# epoch 91
# step 474 : loss 53832.1925538
# min data: -256.0
# max data: 254.0
# min gt: -256.0
# max gt: 254.0
# min pred: -305.01535
# max pred: 351.13443
# epoch 92
# step 474 : loss 54805.8047524
# min data: -256.0
# max data: 254.0
# min gt: -256.0
# max gt: 254.0
# min pred: -314.62515
# max pred: 391.41782
# epoch 93
# step 474 : loss 75144.6307234
# min data: -256.0
# max data: 254.0
# min gt: -256.0
# max gt: 254.0
# min pred: -327.41296
# max pred: 361.76883
# epoch 94
# step 474 : loss 55648.6353945
# min data: -256.0
# max data: 254.0
# min gt: -256.0
# max gt: 254.0
# min pred: -320.63007
# max pred: 356.86725
# epoch 95
# step 474 : loss 51773.9841133
# min data: -256.0
# max data: 254.0
# min gt: -256.0
# max gt: 254.0
# min pred: -320.6795
# max pred: 386.37427
# epoch 96
# step 474 : loss 51200.6503906
# min data: -256.0
# max data: 254.0
# min gt: -256.0
# max gt: 254.0
# min pred: -316.27057
# max pred: 389.21948
# epoch 97
# step 474 : loss 51053.8737309
# min data: -256.0
# max data: 254.0
# min gt: -256.0
# max gt: 254.0
# min pred: -310.2813
# max pred: 353.97046
# epoch 98
# step 474 : loss 52685.5491639
# min data: -256.0
# max data: 254.0
# min gt: -256.0
# max gt: 254.0
# min pred: -322.06924
# max pred: 342.0979
# epoch 99
# step 474 : loss 50913.3974898
# min data: -256.0
# max data: 254.0
# min gt: -256.0
# max gt: 254.0
# min pred: -304.8553
# max pred: 384.39038
# epoch 100
# step 474 : loss 52728.6170402
# min data: -256.0
# max data: 254.0
# min gt: -256.0
# max gt: 254.0
# min pred: -315.2127
# max pred: 375.3022

# %%
x_test, y_test = generator(1)

prediction = net.predict("./unet_trained512/model.ckpt", x_test)
# Out:
# W0921 05:04:50.324588 139905302885760 deprecation.py:323] From /home/urota/anaconda3/envs/py27/lib/python2.7/site-packages/tensorflow/python/training/saver.py:1276: checkpoint_exists (from tensorflow.python.training.checkpoint_management) is deprecated and will be removed in a future version.
# Instructions for updating:
# Use standard file APIs to check for files with this prefix.

# %%
fig, ax = plt.subplots(1, 3, sharex=True, sharey=True, figsize=(12,5))
ax[0].imshow(x_test[0,...,0], aspect="auto")
ax[1].imshow(y_test[0,...,0], aspect="auto")
ax[2].imshow(prediction[0,...,0], aspect="auto")
ax[0].set_title("Input")
ax[1].set_title("Ground truth")
ax[2].set_title("Prediction")
fig.tight_layout()
fig.savefig("../docs/fbp_conv.png")
print(np.min(y_test))
print(np.max(y_test))
print(np.min(prediction))
print(np.max(prediction))
# Out:
# -256.0
# 254.0
# -300.49005
# 305.2682

# %%
def rsnr(rec, oracle):
    "regressed SNR"
    sumP = sum(oracle.reshape(-1))
    sumI = sum(rec.reshape(-1))
    sumIP = sum(oracle.reshape(-1) * rec.reshape(-1))
    sumI2 = sum(rec.reshape(-1)**2)
    A = np.matrix([[sumI2, sumI], [sumI, oracle.size]])
    b = np.matrix([[sumIP], [sumP]])
    c = np.linalg.inv(A)*b  # (A)\b
    rec = c[0, 0]*rec+c[1, 0]
    err = sum((oracle.reshape(-1)-rec.reshape(-1))**2)
    SNR = 10.0*np.log10(sum(oracle.reshape(-1)**2)/err)

    if np.isnan(SNR):
        SNR = 0.0
    return SNR

print(rsnr(y_test, prediction))

import skimage
print(y_test.dtype, y_test.shape)
print(prediction.dtype, prediction.shape)
y_min = np.min(y_test)
p_min = np.min(prediction)
y_max = np.max(y_test)
p_max = np.max(prediction)
print(y_min, p_min, y_max, p_max)
mi = min(y_min, p_min)
ma = max(y_max, p_max)

def normalize(img):
  return img.reshape(512, 512) / 512. + .5

x_n = normalize(x_test)
y_n = normalize(y_test)
p_n = normalize(prediction)
print(skimage.measure.compare_psnr(y_n, p_n))
print(skimage.measure.compare_ssim(y_n, p_n))

print(skimage.measure.compare_psnr(x_n, y_n))
print(skimage.measure.compare_ssim(x_n, y_n))
# Out:
# 28.131557217888915
# /home/urota/anaconda3/envs/py27/lib/python2.7/site-packages/dask/config.py:168: YAMLLoadWarning: calling yaml.load() without Loader=... is deprecated, as the default Loader is unsafe. Please read https://msg.pyyaml.org/load for full details.
#   data = yaml.load(f.read()) or {}
# float64 (1, 512, 512, 1)
# float32 (1, 512, 512, 1)
# -256.0 -300.49005 254.0 305.2682
# 32.28022113880377
# 0.7788823901138525
# 24.41242273476545
# 0.5102669308359836
# /home/urota/anaconda3/envs/py27/lib/python2.7/site-packages/skimage/measure/simple_metrics.py:128: UserWarning: Inputs have mismatched dtype.  Setting data_range based on im_true.
#   warn("Inputs have mismatched dtype.  Setting data_range based on "
# /home/urota/anaconda3/envs/py27/lib/python2.7/site-packages/skimage/measure/_structural_similarity.py:149: UserWarning: Inputs have mismatched dtype.  Setting data_range based on X.dtype.
#   warn("Inputs have mismatched dtype.  Setting data_range based on "

# %%
# %matplotlib inline
import matplotlib.pyplot as plt
import matplotlib
import png
import numpy as np
from sklearn.preprocessing import minmax_scale
plt.gray()

#reader = png.Reader("/mnt/collect/ct_images/Images_png/000086_04_01/079.png")
reader = png.Reader("/mnt/collect/ct_images/Images_png/000001_01_01/109.png")
pngdata = reader.read()
print(pngdata[0])
print(pngdata[1])
print(pngdata[2])
px_array = np.array(map(np.int32, pngdata[2]))
print(px_array.dtype)
print(np.min(px_array))
print(np.max(px_array))

normalized = px_array - 32768
print("#")
print(np.min(normalized))
print(np.max(normalized))

def intensity_windowing(img, a, b):
    # return img
    assert(a < b)
    return np.minimum(255, np.maximum(0, ((img.astype("float") - a) / (b - a)) * 255))

def show_histogram(img):
    fig = plt.figure()
    ax = fig.add_subplot(1,1,1)
    ax.hist(normalized, bins=50)
    fig.show()

normalized = intensity_windowing(normalized, -175, 275)

print(np.min(normalized))
print(np.max(normalized))
plt.imshow(normalized.astype("uint8"))
# Out:
# 512
# 512
# <generator object _iter_bytes_to_values at 0x7f3b05002a00>
# int32
# 29744
# 33970
# #
# -3024
# 1202
# 0.0
# 255.0

# %%
from skimage.transform import radon
import mlem

#shape = (256, 512)
#sino = mlem.mlem.forward_projection(normalized, shape)

theta = np.linspace(0., 360., 64, endpoint=False)
sino = radon(normalized, theta=theta, circle=True)
print(sino.shape, sino.dtype)
print(np.min(sino), np.max(sino))
plt.imshow(sino)
# Out:
# ((512, 64), dtype('float64'))
# (0.0, 66944.86666666671)

# %%
from skimage.transform import iradon

fbp = iradon(sino, theta=theta, circle=True)
plt.imshow(fbp)
