# %%
from __future__ import division, print_function
# %matplotlib inline
import matplotlib.pyplot as plt
import matplotlib
import numpy as np

# %%
import sys
sys.path.append('..')

# %%
from tf_unet import image_util_fbp
from tf_unet import unet
from tf_unet import util

# %%
generator = image_util_fbp.FBPDataProvider("/home/urota/git/tf_unet/data_512/*.png", data_suffix=".png", mask_suffix="_reconst.png")
# Out:
# Number of files used: 474
# Number of channels: 1
# Number of classes: 2

# %%
x_test, y_test= generator(1)
print(generator.len())
# Out:
# 474

# %%
plt.gray()
fig, ax = plt.subplots(1,2, sharey=True, figsize=(8,4))
print(y_test.shape)
print(np.min(x_test), np.max(x_test))
print(np.min(y_test), np.max(y_test))
ax[0].imshow(x_test[0, ..., 0], aspect="auto")
ax[1].imshow(y_test[0, ..., 0], aspect="auto")
# Out:
# (1, 512, 512, 1)
# -256.0 254.0
# -256.0 254.0

# %%
net = unet.Unet(channels=generator.channels, n_class=generator.n_class, cost="euclidean", layers=5, features_root=32)
# Out:
# WARNING: Logging before flag parsing goes to stderr.
# W0901 21:01:56.359704 140657000289664 deprecation_wrapper.py:119] From ../tf_unet/unet.py:193: The name tf.reset_default_graph is deprecated. Please use tf.compat.v1.reset_default_graph instead.
#
# W0901 21:01:56.363959 140657000289664 deprecation_wrapper.py:119] From ../tf_unet/unet.py:198: The name tf.placeholder is deprecated. Please use tf.compat.v1.placeholder instead.
#
# W0901 21:01:56.385410 140657000289664 deprecation_wrapper.py:119] From ../tf_unet/layers.py:25: The name tf.truncated_normal is deprecated. Please use tf.random.truncated_normal instead.
#
# W0901 21:01:56.401928 140657000289664 deprecation.py:506] From ../tf_unet/layers.py:39: calling dropout (from tensorflow.python.ops.nn_ops) with keep_prob is deprecated and will be removed in a future version.
# Instructions for updating:
# Please use `rate` instead of `keep_prob`. Rate should be set to `rate = 1 - keep_prob`.
# W0901 21:01:56.420232 140657000289664 deprecation_wrapper.py:119] From ../tf_unet/layers.py:48: The name tf.nn.max_pool is deprecated. Please use tf.nn.max_pool2d instead.
#
# W0901 21:01:56.919109 140657000289664 deprecation_wrapper.py:119] From ../tf_unet/unet.py:155: The name tf.summary.image is deprecated. Please use tf.compat.v1.summary.image instead.
# Tensor("output_map/conv2d/dropout/mul_1:0", shape=(?, ?, ?, 1), dtype=float32)
# Tensor("preprocessing/Reshape:0", shape=(?, ?, ?, 1), dtype=float32)
# W0901 21:01:57.307518 140657000289664 deprecation_wrapper.py:119] From ../tf_unet/unet.py:165: The name tf.summary.histogram is deprecated. Please use tf.compat.v1.summary.histogram instead.
#
# W0901 21:01:57.753096 140657000289664 deprecation_wrapper.py:119] From ../tf_unet/layers.py:68: The name tf.log is deprecated. Please use tf.math.log instead.

# %%
trainer = unet.Trainer(net, optimizer="adam", batch_size=1, opt_kwargs=dict(learning_rate=0.0001))

# %%
path = trainer.train(generator, "./unet_trained512", training_iters=generator.len(), epochs=101, display_step=2, restore=True)
# Out:
# W0901 21:02:14.915564 140657000289664 deprecation_wrapper.py:119] From ../tf_unet/unet.py:366: The name tf.summary.scalar is deprecated. Please use tf.compat.v1.summary.scalar instead.
#
# W0901 21:02:14.921987 140657000289664 deprecation_wrapper.py:119] From ../tf_unet/unet.py:352: The name tf.train.AdamOptimizer is deprecated. Please use tf.compat.v1.train.AdamOptimizer instead.
#
# W0901 21:02:15.907571 140657000289664 deprecation_wrapper.py:119] From ../tf_unet/unet.py:373: The name tf.summary.merge_all is deprecated. Please use tf.compat.v1.summary.merge_all instead.
#
# W0901 21:02:15.910676 140657000289664 deprecation_wrapper.py:119] From ../tf_unet/unet.py:374: The name tf.global_variables_initializer is deprecated. Please use tf.compat.v1.global_variables_initializer instead.
#
# W0901 21:02:19.708585 140657000289664 deprecation_wrapper.py:119] From ../tf_unet/unet.py:431: The name tf.summary.FileWriter is deprecated. Please use tf.compat.v1.summary.FileWriter instead.
# min data: -256.0
# max data: 254.0
# min gt: -256.0
# max gt: 254.0
# min pred: -263.5779
# max pred: 270.67242
# epoch 0
# step 474 : loss 1930710.57906
# W0901 21:05:58.559717 140657000289664 deprecation_wrapper.py:119] From ../tf_unet/unet.py:295: The name tf.train.Saver is deprecated. Please use tf.compat.v1.train.Saver instead.
# min data: -256.0
# max data: 254.0
# min gt: -256.0
# max gt: 254.0
# min pred: -514.6632
# max pred: 245.94334
# epoch 1
# step 474 : loss 626247.691002
# min data: -256.0
# max data: 254.0
# min gt: -256.0
# max gt: 254.0
# min pred: -373.1715
# max pred: 284.9628
# epoch 2
# step 474 : loss 530017.476678
# min data: -256.0
# max data: 254.0
# min gt: -256.0
# max gt: 254.0
# min pred: -329.4736
# max pred: 284.55862
# epoch 3
# step 474 : loss 460562.347491
# min data: -256.0
# max data: 254.0
# min gt: -256.0
# max gt: 254.0
# min pred: -307.31213
# max pred: 277.1726
# epoch 4
# step 474 : loss 419902.800262
# min data: -256.0
# max data: 254.0
# min gt: -256.0
# max gt: 254.0
# min pred: -323.9778
# max pred: 253.98737
# epoch 5
# step 474 : loss 388224.244661
# min data: -256.0
# max data: 254.0
# min gt: -256.0
# max gt: 254.0
# min pred: -318.57507
# max pred: 267.38928
# epoch 6
# step 474 : loss 349864.305693
# min data: -256.0
# max data: 254.0
# min gt: -256.0
# max gt: 254.0
# min pred: -316.77942
# max pred: 277.28418
# epoch 7
# step 474 : loss 316347.776705
# min data: -256.0
# max data: 254.0
# min gt: -256.0
# max gt: 254.0
# min pred: -318.59766
# max pred: 290.25223
# epoch 8
# step 474 : loss 294877.190718
# min data: -256.0
# max data: 254.0
# min gt: -256.0
# max gt: 254.0
# min pred: -310.62955
# max pred: 295.20258
# epoch 9
# step 474 : loss 290567.413308
# min data: -256.0
# max data: 254.0
# min gt: -256.0
# max gt: 254.0
# min pred: -300.73584
# max pred: 306.91827
# epoch 10
# step 474 : loss 261208.830704
# min data: -256.0
# max data: 254.0
# min gt: -256.0
# max gt: 254.0
# min pred: -286.7798
# max pred: 308.5738
# epoch 11
# step 474 : loss 236605.947953
# min data: -256.0
# max data: 254.0
# min gt: -256.0
# max gt: 254.0
# min pred: -281.2756
# max pred: 333.92404
# epoch 12
# step 474 : loss 218492.546298
# min data: -256.0
# max data: 254.0
# min gt: -256.0
# max gt: 254.0
# min pred: -271.89502
# max pred: 342.5649
# epoch 13
# step 474 : loss 209535.773503
# min data: -256.0
# max data: 254.0
# min gt: -256.0
# max gt: 254.0
# min pred: -263.20044
# max pred: 347.07013
# epoch 14
# step 474 : loss 206969.392619
# min data: -256.0
# max data: 254.0
# min gt: -256.0
# max gt: 254.0
# min pred: -260.74365
# max pred: 339.9711
# epoch 15
# step 474 : loss 209753.871242
# min data: -256.0
# max data: 254.0
# min gt: -256.0
# max gt: 254.0
# min pred: -260.52487
# max pred: 336.56345
# epoch 16
# step 474 : loss 212167.622116
# min data: -256.0
# max data: 254.0
# min gt: -256.0
# max gt: 254.0
# min pred: -257.9403
# max pred: 334.10934
# epoch 17
# step 474 : loss 193319.102996
# min data: -256.0
# max data: 254.0
# min gt: -256.0
# max gt: 254.0
# min pred: -256.0742
# max pred: 334.09283
# epoch 18
# step 474 : loss 190116.048968
# min data: -256.0
# max data: 254.0
# min gt: -256.0
# max gt: 254.0
# min pred: -256.09653
# max pred: 335.34406
# epoch 19
# step 474 : loss 184738.899319
# min data: -256.0
# max data: 254.0
# min gt: -256.0
# max gt: 254.0
# min pred: -256.12292
# max pred: 322.27383
# epoch 20
# step 474 : loss 189943.142924
# min data: -256.0
# max data: 254.0
# min gt: -256.0
# max gt: 254.0
# min pred: -256.14838
# max pred: 336.09058
# epoch 21
# step 474 : loss 188809.614266
# min data: -256.0
# max data: 254.0
# min gt: -256.0
# max gt: 254.0
# min pred: -256.17316
# max pred: 326.35785
# epoch 22
# step 474 : loss 179394.859264
# min data: -256.0
# max data: 254.0
# min gt: -256.0
# max gt: 254.0
# min pred: -256.19843
# max pred: 327.4272
# epoch 23
# step 474 : loss 175626.196223
# min data: -256.0
# max data: 254.0
# min gt: -256.0
# max gt: 254.0
# min pred: -256.2241
# max pred: 320.78378
# epoch 24
# step 474 : loss 172752.503235
# min data: -256.0
# max data: 254.0
# min gt: -256.0
# max gt: 254.0
# min pred: -256.25073
# max pred: 312.98944
# epoch 25
# step 474 : loss 171118.648928
# min data: -256.0
# max data: 254.0
# min gt: -256.0
# max gt: 254.0
# min pred: -256.2781
# max pred: 316.56094
# epoch 26
# step 474 : loss 169383.979297
# min data: -256.0
# max data: 254.0
# min gt: -256.0
# max gt: 254.0
# min pred: -260.8744
# max pred: 314.2744
# epoch 27
# step 474 : loss 166958.153151
# min data: -256.0
# max data: 254.0
# min gt: -256.0
# max gt: 254.0
# min pred: -256.9963
# max pred: 313.56085
# epoch 28
# step 474 : loss 166500.910515
# min data: -256.0
# max data: 254.0
# min gt: -256.0
# max gt: 254.0
# min pred: -264.1756
# max pred: 314.35886
# epoch 29
# step 474 : loss 168062.005465
# min data: -256.0
# max data: 254.0
# min gt: -256.0
# max gt: 254.0
# min pred: -256.39297
# max pred: 305.4677
# epoch 30
# step 474 : loss 197752.624205
# min data: -256.0
# max data: 254.0
# min gt: -256.0
# max gt: 254.0
# min pred: -256.4109
# max pred: 304.13733
# epoch 31
# step 474 : loss 167827.385923
# min data: -256.0
# max data: 254.0
# min gt: -256.0
# max gt: 254.0
# min pred: -256.43146
# max pred: 308.6325
# epoch 32
# step 474 : loss 162779.631692
# min data: -256.0
# max data: 254.0
# min gt: -256.0
# max gt: 254.0
# min pred: -256.4554
# max pred: 302.156
# epoch 33
# step 474 : loss 161835.393044
# min data: -256.0
# max data: 254.0
# min gt: -256.0
# max gt: 254.0
# min pred: -264.46973
# max pred: 305.14066
# epoch 34
# step 474 : loss 159389.582647
# min data: -256.0
# max data: 254.0
# min gt: -256.0
# max gt: 254.0
# min pred: -264.85855
# max pred: 299.21265
# epoch 35
# step 474 : loss 159120.563415
# min data: -256.0
# max data: 254.0
# min gt: -256.0
# max gt: 254.0
# min pred: -259.22818
# max pred: 302.71747
# epoch 36
# step 474 : loss 157418.817185
# min data: -256.0
# max data: 254.0
# min gt: -256.0
# max gt: 254.0
# min pred: -260.491
# max pred: 299.78958
# epoch 37
# step 474 : loss 156608.551939
# min data: -256.0
# max data: 254.0
# min gt: -256.0
# max gt: 254.0
# min pred: -256.59393
# max pred: 297.5148
# epoch 38
# step 474 : loss 156206.532466
# min data: -256.0
# max data: 254.0
# min gt: -256.0
# max gt: 254.0
# min pred: -256.62134
# max pred: 297.9925
# epoch 39
# step 474 : loss 156332.992249
# min data: -256.0
# max data: 254.0
# min gt: -256.0
# max gt: 254.0
# min pred: -258.6607
# max pred: 294.72952
# epoch 40
# step 474 : loss 166306.188423
# min data: -256.0
# max data: 254.0
# min gt: -256.0
# max gt: 254.0
# min pred: -272.2681
# max pred: 301.69833
# epoch 41
# step 474 : loss 157301.091822
# min data: -256.0
# max data: 254.0
# min gt: -256.0
# max gt: 254.0
# min pred: -256.69983
# max pred: 304.4499
# epoch 42
# step 474 : loss 154393.656135
# min data: -256.0
# max data: 254.0
# min gt: -256.0
# max gt: 254.0
# min pred: -256.7265
# max pred: 290.1481
# epoch 43
# step 474 : loss 151773.822715
# min data: -256.0
# max data: 254.0
# min gt: -256.0
# max gt: 254.0
# min pred: -256.7546
# max pred: 302.89667
# epoch 44
# step 474 : loss 151213.965639
# min data: -256.0
# max data: 254.0
# min gt: -256.0
# max gt: 254.0
# min pred: -256.78326
# max pred: 306.2858
# epoch 45
# step 474 : loss 149805.854842
# min data: -256.0
# max data: 254.0
# min gt: -256.0
# max gt: 254.0
# min pred: -256.81198
# max pred: 307.25278
# epoch 46
# step 474 : loss 149282.878914
# min data: -256.0
# max data: 254.0
# min gt: -256.0
# max gt: 254.0
# min pred: -256.84174
# max pred: 301.57382
# epoch 47
# step 474 : loss 149001.140893
# min data: -256.0
# max data: 254.0
# min gt: -256.0
# max gt: 254.0
# min pred: -256.87164
# max pred: 293.16467
# epoch 48
# step 474 : loss 147832.349092
# min data: -256.0
# max data: 254.0
# min gt: -256.0
# max gt: 254.0
# min pred: -256.93442
# max pred: 301.31943
# epoch 49
# step 474 : loss 147840.030785
# min data: -256.0
# max data: 254.0
# min gt: -256.0
# max gt: 254.0
# min pred: -256.9298
# max pred: 298.11203
# epoch 50
# step 474 : loss 147349.896616
# min data: -256.0
# max data: 254.0
# min gt: -256.0
# max gt: 254.0
# min pred: -256.95868
# max pred: 300.0581
# epoch 51
# step 474 : loss 145934.187846
# min data: -256.0
# max data: 254.0
# min gt: -256.0
# max gt: 254.0
# min pred: -256.98816
# max pred: 298.41956
# epoch 52
# step 474 : loss 148237.836535
# min data: -256.0
# max data: 254.0
# min gt: -256.0
# max gt: 254.0
# min pred: -257.01633
# max pred: 301.74902
# epoch 53
# step 474 : loss 153610.441291
# min data: -256.0
# max data: 254.0
# min gt: -256.0
# max gt: 254.0
# min pred: -266.4234
# max pred: 302.85156
# epoch 54
# step 474 : loss 145537.813889
# min data: -256.0
# max data: 254.0
# min gt: -256.0
# max gt: 254.0
# min pred: -257.06915
# max pred: 295.43674
# epoch 55
# step 474 : loss 143714.202598
# min data: -256.0
# max data: 254.0
# min gt: -256.0
# max gt: 254.0
# min pred: -257.09793
# max pred: 302.22256
# epoch 56
# step 474 : loss 143202.909773
# min data: -256.0
# max data: 254.0
# min gt: -256.0
# max gt: 254.0
# min pred: -257.12732
# max pred: 302.2841
# epoch 57
# step 474 : loss 142541.500618
# min data: -256.0
# max data: 254.0
# min gt: -256.0
# max gt: 254.0
# min pred: -257.15726
# max pred: 293.84253
# epoch 58
# step 474 : loss 142793.081487
# min data: -256.0
# max data: 254.0
# min gt: -256.0
# max gt: 254.0
# min pred: -257.18726
# max pred: 292.88303
# epoch 59
# step 474 : loss 141710.206961
# min data: -256.0
# max data: 254.0
# min gt: -256.0
# max gt: 254.0
# min pred: -257.21725
# max pred: 294.0956
# epoch 60
# step 474 : loss 142208.285296
# min data: -256.0
# max data: 254.0
# min gt: -256.0
# max gt: 254.0
# min pred: -257.24753
# max pred: 299.60962
# epoch 61
# step 474 : loss 142143.038168
# min data: -256.0
# max data: 254.0
# min gt: -256.0
# max gt: 254.0
# min pred: -257.27805
# max pred: 291.8507
# epoch 62
# step 474 : loss 141156.814214
# min data: -256.0
# max data: 254.0
# min gt: -256.0
# max gt: 254.0
# min pred: -257.30664
# max pred: 292.0558
# epoch 63
# step 474 : loss 140824.752015
# min data: -256.0
# max data: 254.0
# min gt: -256.0
# max gt: 254.0
# min pred: -257.33682
# max pred: 290.98193
# epoch 64
# step 474 : loss 140123.043725
# min data: -256.0
# max data: 254.0
# min gt: -256.0
# max gt: 254.0
# min pred: -257.3667
# max pred: 294.2667
# epoch 65
# step 474 : loss 139549.807007
# min data: -256.0
# max data: 254.0
# min gt: -256.0
# max gt: 254.0
# min pred: -257.39682
# max pred: 294.5348
# epoch 66
# step 474 : loss 139620.113681
# min data: -256.0
# max data: 254.0
# min gt: -256.0
# max gt: 254.0
# min pred: -257.4274
# max pred: 295.74847
# epoch 67
# step 474 : loss 164138.128152
# min data: -256.0
# max data: 254.0
# min gt: -256.0
# max gt: 254.0
# min pred: -257.44955
# max pred: 294.01544
# epoch 68
# step 474 : loss 139738.947101
# min data: -256.0
# max data: 254.0
# min gt: -256.0
# max gt: 254.0
# min pred: -257.47528
# max pred: 294.05505
# epoch 69
# step 474 : loss 138097.745393
# min data: -256.0
# max data: 254.0
# min gt: -256.0
# max gt: 254.0
# min pred: -257.50287
# max pred: 296.69662
# epoch 70
# step 474 : loss 138066.420462
# min data: -256.0
# max data: 254.0
# min gt: -256.0
# max gt: 254.0
# min pred: -257.53223
# max pred: 293.3494
# epoch 71
# step 474 : loss 137617.569451
# min data: -256.0
# max data: 254.0
# min gt: -256.0
# max gt: 254.0
# min pred: -275.47568
# max pred: 293.12772
# epoch 72
# step 474 : loss 136950.089199
# min data: -256.0
# max data: 254.0
# min gt: -256.0
# max gt: 254.0
# min pred: -257.59305
# max pred: 295.2708
# epoch 73
# step 474 : loss 137305.378138
# min data: -256.0
# max data: 254.0
# min gt: -256.0
# max gt: 254.0
# min pred: -257.62372
# max pred: 293.374
# epoch 74
# step 474 : loss 137413.069995
# min data: -256.0
# max data: 254.0
# min gt: -256.0
# max gt: 254.0
# min pred: -306.03064
# max pred: 297.1279
# epoch 75
# step 474 : loss 136941.512407
# min data: -256.0
# max data: 254.0
# min gt: -256.0
# max gt: 254.0
# min pred: -257.68524
# max pred: 296.0265
# epoch 76
# step 474 : loss 136716.520878
# min data: -256.0
# max data: 254.0
# min gt: -256.0
# max gt: 254.0
# min pred: -257.7152
# max pred: 296.44443
# epoch 77
# step 474 : loss 135372.669143
# min data: -256.0
# max data: 254.0
# min gt: -256.0
# max gt: 254.0
# min pred: -257.74557
# max pred: 294.1292
# epoch 78
# step 474 : loss 136313.471515
# min data: -256.0
# max data: 254.0
# min gt: -256.0
# max gt: 254.0
# min pred: -257.7765
# max pred: 294.63852
# epoch 79
# step 474 : loss 136326.839028
# min data: -256.0
# max data: 254.0
# min gt: -256.0
# max gt: 254.0
# min pred: -326.5922
# max pred: 296.05908
# epoch 80
# step 474 : loss 135394.715333
# min data: -256.0
# max data: 254.0
# min gt: -256.0
# max gt: 254.0
# min pred: -257.83594
# max pred: 295.2705
# epoch 81
# step 474 : loss 135105.403891
# min data: -256.0
# max data: 254.0
# min gt: -256.0
# max gt: 254.0
# min pred: -257.86557
# max pred: 297.25763
# epoch 82
# step 474 : loss 134770.519047
# min data: -256.0
# max data: 254.0
# min gt: -256.0
# max gt: 254.0
# min pred: -257.89594
# max pred: 293.99112
# epoch 83
# step 474 : loss 134875.929778
# min data: -256.0
# max data: 254.0
# min gt: -256.0
# max gt: 254.0
# min pred: -260.7003
# max pred: 295.45905
# epoch 84
# step 474 : loss 134092.772618
# min data: -256.0
# max data: 254.0
# min gt: -256.0
# max gt: 254.0
# min pred: -294.58185
# max pred: 298.61063
# epoch 85
# step 474 : loss 134446.894055
# min data: -256.0
# max data: 254.0
# min gt: -256.0
# max gt: 254.0
# min pred: -257.98578
# max pred: 294.03238
# epoch 86
# step 474 : loss 133687.548758
# min data: -256.0
# max data: 254.0
# min gt: -256.0
# max gt: 254.0
# min pred: -316.75305
# max pred: 295.98328
# epoch 87
# step 474 : loss 133781.523681
# min data: -256.0
# max data: 254.0
# min gt: -256.0
# max gt: 254.0
# min pred: -290.90994
# max pred: 297.79108
# epoch 88
# step 474 : loss 134179.498708
# min data: -256.0
# max data: 254.0
# min gt: -256.0
# max gt: 254.0
# min pred: -259.24652
# max pred: 295.99857
# epoch 89
# step 474 : loss 134607.632034
# min data: -256.0
# max data: 254.0
# min gt: -256.0
# max gt: 254.0
# min pred: -331.91458
# max pred: 299.08588
# epoch 90
# step 474 : loss 133882.503626
# min data: -256.0
# max data: 254.0
# min gt: -256.0
# max gt: 254.0
# min pred: -363.65762
# max pred: 297.84875
# epoch 91
# step 474 : loss 132367.889088
# min data: -256.0
# max data: 254.0
# min gt: -256.0
# max gt: 254.0
# min pred: -275.41333
# max pred: 298.97067
# epoch 92
# step 474 : loss 132680.810755
# min data: -256.0
# max data: 254.0
# min gt: -256.0
# max gt: 254.0
# min pred: -258.3418
# max pred: 297.2751
# epoch 93
# step 474 : loss 132536.437291
# min data: -256.0
# max data: 254.0
# min gt: -256.0
# max gt: 254.0
# min pred: -258.22348
# max pred: 297.16
# epoch 94
# step 474 : loss 131923.396934
# min data: -256.0
# max data: 254.0
# min gt: -256.0
# max gt: 254.0
# min pred: -271.1891
# max pred: 298.33435
# epoch 95
# step 474 : loss 132103.121716
# min data: -256.0
# max data: 254.0
# min gt: -256.0
# max gt: 254.0
# min pred: -283.0465
# max pred: 300.0175
# epoch 96
# step 474 : loss 132402.595975
# min data: -256.0
# max data: 254.0
# min gt: -256.0
# max gt: 254.0
# min pred: -305.42426
# max pred: 302.04272
# epoch 97
# step 474 : loss 130753.846764
# min data: -256.0
# max data: 254.0
# min gt: -256.0
# max gt: 254.0
# min pred: -269.7041
# max pred: 295.5218
# epoch 98
# step 474 : loss 131130.168261
# min data: -256.0
# max data: 254.0
# min gt: -256.0
# max gt: 254.0
# min pred: -273.49677
# max pred: 299.8493
# epoch 99
# step 474 : loss 132100.847739
# min data: -256.0
# max data: 254.0
# min gt: -256.0
# max gt: 254.0
# min pred: -276.985
# max pred: 297.45868
# epoch 100
# step 474 : loss 130806.872053
# min data: -256.0
# max data: 254.0
# min gt: -256.0
# max gt: 254.0
# min pred: -324.82538
# max pred: 298.7438

# %%
x_test, y_test = generator(1)

prediction = net.predict("./unet_trained512/model.ckpt", x_test)
# Out:
# W0902 07:54:05.854562 140657000289664 deprecation.py:323] From /home/urota/anaconda3/envs/py27/lib/python2.7/site-packages/tensorflow/python/training/saver.py:1276: checkpoint_exists (from tensorflow.python.training.checkpoint_management) is deprecated and will be removed in a future version.
# Instructions for updating:
# Use standard file APIs to check for files with this prefix.

# %%
fig, ax = plt.subplots(1, 3, sharex=True, sharey=True, figsize=(12,5))
ax[0].imshow(x_test[0,...,0], aspect="auto")
ax[1].imshow(y_test[0,...,0], aspect="auto")
ax[2].imshow(prediction[0,...,0], aspect="auto")
ax[0].set_title("Input")
ax[1].set_title("Ground truth")
ax[2].set_title("Prediction")
fig.tight_layout()
fig.savefig("../docs/fbp_conv.png")
print(np.min(y_test))
print(np.max(y_test))
print(np.min(prediction))
print(np.max(prediction))
# Out:
# -256.0
# 254.0
# -258.4415
# 263.93665

# %%
def rsnr(rec, oracle):
    "regressed SNR"
    sumP = sum(oracle.reshape(-1))
    sumI = sum(rec.reshape(-1))
    sumIP = sum(oracle.reshape(-1) * rec.reshape(-1))
    sumI2 = sum(rec.reshape(-1)**2)
    A = np.matrix([[sumI2, sumI], [sumI, oracle.size]])
    b = np.matrix([[sumIP], [sumP]])
    c = np.linalg.inv(A)*b  # (A)\b
    rec = c[0, 0]*rec+c[1, 0]
    err = sum((oracle.reshape(-1)-rec.reshape(-1))**2)
    SNR = 10.0*np.log10(sum(oracle.reshape(-1)**2)/err)

    if np.isnan(SNR):
        SNR = 0.0
    return SNR

print(rsnr(y_test, prediction))

import skimage
print(y_test.dtype, y_test.shape)
print(prediction.dtype, prediction.shape)
y_min = np.min(y_test)
p_min = np.min(prediction)
y_max = np.max(y_test)
p_max = np.max(prediction)
print(y_min, p_min, y_max, p_max)
mi = min(y_min, p_min)
ma = max(y_max, p_max)

def normalize(img):
  return img.reshape(512, 512) / 512. + .5

x_n = normalize(x_test)
y_n = normalize(y_test)
p_n = normalize(prediction)
print(skimage.measure.compare_psnr(y_n, p_n))
print(skimage.measure.compare_ssim(y_n, p_n))

print(skimage.measure.compare_psnr(x_n, y_n))
print(skimage.measure.compare_ssim(x_n, y_n))
# Out:
# 19.32099448946657
# /home/urota/anaconda3/envs/py27/lib/python2.7/site-packages/dask/config.py:168: YAMLLoadWarning: calling yaml.load() without Loader=... is deprecated, as the default Loader is unsafe. Please read https://msg.pyyaml.org/load for full details.
#   data = yaml.load(f.read()) or {}
# float64 (1, 512, 512, 1)
# float32 (1, 512, 512, 1)
# -256.0 -258.4415 254.0 263.93665
# 28.495369492295435
# 0.854413586083789
# 31.25176895101488
# 0.9515823975678322
# /home/urota/anaconda3/envs/py27/lib/python2.7/site-packages/skimage/measure/simple_metrics.py:128: UserWarning: Inputs have mismatched dtype.  Setting data_range based on im_true.
#   warn("Inputs have mismatched dtype.  Setting data_range based on "
# /home/urota/anaconda3/envs/py27/lib/python2.7/site-packages/skimage/measure/_structural_similarity.py:149: UserWarning: Inputs have mismatched dtype.  Setting data_range based on X.dtype.
#   warn("Inputs have mismatched dtype.  Setting data_range based on "

# %%
# %matplotlib inline
import matplotlib.pyplot as plt
import matplotlib
import png
import numpy as np
from sklearn.preprocessing import minmax_scale
plt.gray()

#reader = png.Reader("/mnt/collect/ct_images/Images_png/000086_04_01/079.png")
reader = png.Reader("/mnt/collect/ct_images/Images_png/000001_01_01/109.png")
pngdata = reader.read()
print(pngdata[0])
print(pngdata[1])
print(pngdata[2])
px_array = np.array(map(np.int32, pngdata[2]))
print(px_array.dtype)
print(np.min(px_array))
print(np.max(px_array))

normalized = px_array - 32768
print("#")
print(np.min(normalized))
print(np.max(normalized))

def intensity_windowing(img, a, b):
    # return img
    assert(a < b)
    return np.minimum(255, np.maximum(0, ((img.astype("float") - a) / (b - a)) * 255))

def show_histogram(img):
    fig = plt.figure()
    ax = fig.add_subplot(1,1,1)
    ax.hist(normalized, bins=50)
    fig.show()

normalized = intensity_windowing(normalized, -175, 275)

print(np.min(normalized))
print(np.max(normalized))
plt.imshow(normalized.astype("uint8"))
# Out:
# 512
# 512
# <generator object _iter_bytes_to_values at 0x7fc6857db1e0>
# int32
# 29744
# 33970
# #
# -3024
# 1202
# 0.0
# 255.0

# %%
from skimage.transform import radon
import mlem

#shape = (256, 512)
#sino = mlem.mlem.forward_projection(normalized, shape)

theta = np.linspace(0., 360., 64, endpoint=False)
sino = radon(normalized, theta=theta, circle=True)
print(sino.shape, sino.dtype)
print(np.min(sino), np.max(sino))
plt.imshow(sino)
# Out:
# ((512, 64), dtype('float64'))
# (0.0, 66944.86666666671)

# %%
from skimage.transform import iradon

fbp = iradon(sino, theta=theta, circle=True)
plt.imshow(fbp)
